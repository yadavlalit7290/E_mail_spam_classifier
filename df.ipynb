# %%
import pandas as pd
import pickle

# %%
import pandas as pd

# Try reading the CSV file with different encodings
try_encodings = ['utf-8', 'latin1', 'utf-16']

for encoding in try_encodings:
    try:
        df = pd.read_csv('spam.csv', encoding=encoding)
        break  # If successful, exit the loop
    except UnicodeDecodeError:
        print(f"Failed to read with {encoding} encoding. Trying next...")

# Now you can work with your DataFrame
pd.set_option('display.max_columns', 200)  # Set display option if needed
df.head()

# Display null value counts
df.isnull().sum()
# Out:
# Failed to read with utf-8 encoding. Trying next...
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
spam = df[df['v1'] == 'spam']

# %%
spam = spam.reset_index()
spam = spam.drop(columns=['index'])

# %%
spam
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 0    spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 1    spam  FreeMsg Hey there darling it's been 3 week's n...        NaN
# 2    spam  WINNER!! As a valued network customer you have...        NaN
# 3    spam  Had your mobile 11 months or more? U R entitle...        NaN
# 4    spam  SIX chances to win CASH! From 100 to 20,000 po...        NaN
# ..    ...                                                ...        ...
# 742  spam  Want explicit SEX in 30 secs? Ring 02073162414...        NaN
# 743  spam  ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE ...        NaN
# 744  spam  Had your contract mobile 11 Mnths? Latest Moto...        NaN
# 745  spam  REMINDER FROM O2: To get 2.50 pounds free call...        NaN
# 746  spam  This is the 2nd time we have tried 2 contact u...        NaN
#
#     Unnamed: 3 Unnamed: 4
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN
# ..         ...        ...
# 742        NaN        NaN
# 743        NaN        NaN
# 744        NaN        NaN
# 745        NaN        NaN
# 746        NaN        NaN
#
# [747 rows x 5 columns]

# %%
spam['v2'][745]
# Out:
# 'REMINDER FROM O2: To get 2.50 pounds free call credit and details of great offers pls reply 2 this text with your valid name, house no and postcode'

# %%
ham = df[df['v1'] == 'ham']
ham = ham.reset_index()
ham = ham.drop(columns=['index'])
ham
# Out:
#        v1                                                 v2 Unnamed: 2  \
# 0     ham  Go until jurong point, crazy.. Available only ...        NaN
# 1     ham                      Ok lar... Joking wif u oni...        NaN
# 2     ham  U dun say so early hor... U c already then say...        NaN
# 3     ham  Nah I don't think he goes to usf, he lives aro...        NaN
# 4     ham  Even my brother is not like to speak with me. ...        NaN
# ...   ...                                                ...        ...
# 4820  ham                                       Huh y lei...        NaN
# 4821  ham              Will Ì_ b going to esplanade fr home?        NaN
# 4822  ham  Pity, * was in mood for that. So...any other s...        NaN
# 4823  ham  The guy did some bitching but I acted like i'd...        NaN
# 4824  ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 4820        NaN        NaN
# 4821        NaN        NaN
# 4822        NaN        NaN
# 4823        NaN        NaN
# 4824        NaN        NaN
#
# [4825 rows x 5 columns]

# %%
ham['v2'][483]
# Out:
# "Fuck babe ... I miss you already, you know ? Can't you let me send you some money towards your net ? I need you ... I want you ... I crave you ..."
